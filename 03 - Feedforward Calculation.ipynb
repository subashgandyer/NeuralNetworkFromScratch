# %% [markdown]
# ### Consider the following example of a neural network

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Given,
#
# w = [0, 1]
#
# b = 0
#
# x = [2, 3]
#
# O1 = ?

# %%
w = [0,1]
b = 0
x = [2,3]

# %%
def sigmoid(x):
  return None # code goes here

# %%
import numpy as np
def feedforward(w,x,b):
    return None # code goes here

# %%
h1 = h2 = feedforward(w, x, b)
h2

# %%
o1 = feedforward(w, [h1,h2], b)
o1

# %% [markdown]
# ### Expected Outputs

# %% [markdown]
# ![image.png](attachment:image.png)
